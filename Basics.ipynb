# %%
print("testing")

# %%
# %sql
Select "Testing my SQl command"

# %% [markdown]
# # Testing magic command for markdown
#
# - testing 1
# - testing 2
# - testing 3

# %%
# %python

print("testing python magic command")

# %%
# %run ./Includes/Library

# %%
print(name)

# %%
# %fs ls

# %%
# %fs ls dbfs:/databricks-datasets/

# %%
dbutils.fs.ls ('dbfs:/databricks-datasets/')

files = dbutils.fs.ls ('dbfs:/databricks-datasets/')

##print (files)



display(files)
#Dbutils is more powerful than %fs magic command

# %%
varible = "testing"
Var2 = "testing 2"
var3 = "testing3£" 

print(varible)
print(Var2)
print(var3)
